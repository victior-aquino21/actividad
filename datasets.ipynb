# %% [markdown]
# # dataset profesores y trabajadores

# %%
import pandas as pd
import random

id = ["0","1","2","3","4"]
nombres = ["Juan","NAN","Carlos","Ana","Luis","Pedro","Sofia","Miguel","Laura","Jorge"]
apellidos = ["Lopez","Garcia","Perez","Hernandez","Ramirez","Gomez","Diaz","Castro","Mendez","Vasquez"]
departamentos = ["Ventas","Recursos Humanos","Finanzas","IT","Logistica"]
ciudades = ["Guatemala","Mixco","Villa Nueva","Antigua","Escuintla"]
estados = ["Activo","Inactivo"]

trabajadores = []
  
for i in range(1,51):
    trabajador = {
        "id_trabajador": i,
        "nombre": random.choice(nombres),
        "apellido": random.choice(apellidos),
        "edad": random.randint(20,60),
        "genero": random.choice(["M","F"]),
        "departamento": random.choice(departamentos),
        "salario": random.randint(3000,12000),
      
    }
    trabajadores.append(trabajador)

df_trabajadores = pd.DataFrame(trabajadores)
data=[

# %%
id = ["0","1","2","3","4"]
materias = ["Matematicas","Historia","Fisica","Quimica","Biologia","Ingles","Programacion"]
niveles = ["Primaria","Basico","Diversificado","Universidad"]

profesores = []

for i in range(1,51):
    profesor = {
        "id_profesor": i,
        "nombre": random.choice(nombres),
        "apellido": random.choice(apellidos),
        "edad": random.randint(25,65),
        "genero": random.choice(["M","F"]),
        "materia": random.choice(materias),
        "nivel": random.choice(niveles),
    }
    profesores.append(profesor)

df_profesores = pd.DataFrame(profesores)

print("DATASET TRABAJADORES")
print(df_trabajadores.head())

print("\nDATASET PROFESORES")
print(df_profesores.head())

df_trabajadores.to_csv("trabajadores.csv", index=False)
df_profesores.to_csv("profesores.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       5 profesores = []
#       7 for i in range(1,51):
#       8     profesor = {
#       9         "id_profesor": i,
# ---> 10         "nombre": random.choice(nombres),
#      11         "apellido": random.choice(apellidos),
#      12         "edad": random.randint(25,65),
#      13         "genero": random.choice(["M","F"]),
#      14         "materia": random.choice(materias),
#      15         "nivel": random.choice(niveles),
#      16     }
#      17     profesores.append(profesor)
#      19 df_profesores = pd.DataFrame(profesores)
#
# NameError: name 'random' is not defined

# %%
import pandas as pd
import numpy as np

data = {'A': [1, 2, np.nan], 'B': [5, np.nan, np.nan], 'C': [1, 2, 3]}
df = pd.DataFrame(data)

print(df.isnull().sum())
# Out:
# A    1
# B    2
# C    0
# dtype: int64
